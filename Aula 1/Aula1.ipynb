# %%
import pyautogui
import time
import pyperclip

# # acessando link do drive a baixando a planilha
# pyautogui.PAUSE = 1
# pyautogui.alert('vai começar, aperte ok e aguarde')
# pyautogui.hotkey('ctrl', 't')
# link = "https://drive.google.com/drive/folders/1h09OBdOmkEYRqzltR0uLOhncAkr_xDR4"
# pyperclip.copy(link)
# pyautogui.hotkey('ctrl', 'v')
# pyautogui.press("enter")
# time.sleep(5)
# pyautogui.click(385, 348)
# time.sleep(2)
# pyautogui.click(1163, 188)
# time.sleep(2)
# pyautogui.click(997, 561)
# time.sleep(5)

# abrindo e exibindo a tabela
import pandas as pd

df = pd.read_excel(r'C:\Users\User\Downloads\Vendas - Dez.xlsx')
display(df)

# calculando e obtendo os dados que precisamos
faturamento = df['Valor Final'].sum()
quantidade = df['Quantidade'].sum()
print(faturamento, quantidade)

# enviando o email
pyautogui.hotkey('ctrl', 't')
pyautogui.write('gmail.com')
pyautogui.press('enter')
time.sleep(3)
pyautogui.click(82, 197)
time.sleep(2)
pyautogui.write('tanicruz112@gmail.com')
time.sleep(1)
pyautogui.press('enter')
pyautogui.press('tab')
pyautogui.write('Relatório de Vendas de vendas')
pyautogui.press('tab')
texto = f"""Prezados, bom dia.
A quantidade vendida foi de {quantidade:,} e o faturamento foi de R$ {faturamento:,.2f}
At.te."""
pyperclip.copy(texto)
pyautogui.hotkey('ctrl', 'v')
pyautogui.click(830, 639)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
time.sleep(10)
print(pyautogui.position())
# Out:
# Point(x=830, y=639)

# %%
# Out:
# oi
